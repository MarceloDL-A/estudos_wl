# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Carregando o dataset Iris
iris = sns.load_dataset('iris')

# Criando um box plot para o comprimento das pétalas por espécie
sns.boxplot(data=iris, x='species', y='petal_length')
plt.title('Box Plot do Comprimento das Pétalas por Espécie')
plt.show()

# %%
iris.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4560\3501189239.py in ?()
# ----> 1 iris.data
#
# c:\Users\Marcelo DL\Desktop\VSCode\Data Science\Estatística\estat_env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'data'
